# %% [markdown]
# # Load profiles and save it as a parquet file

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
from load_profiles import load_profiles

# %% [markdown]
# ## Load metadata

# %%
plates = pd.read_csv("../../datasets/metadata/plate.csv.gz")
wells = pd.read_csv("../../datasets/metadata/well.csv.gz")
compound = pd.read_csv("../../datasets/metadata/compound.csv.gz")
orf = pd.read_csv("../../datasets/metadata/orf.csv.gz")

# %% [markdown]
# ## Load raw profiles
#
# Setting `columns = None` below will load all of the features.
#
# <div class="alert alert-warning">
# WARNING: Files are located in S3. This loop loads only two features per each sampled plate; loading many feature and/or many plates can take several minutes.
# </div>

# %%
profiles = load_profiles(
    dataset="cpg0016-jump-fixed",
    source="source_4",
    batch="2021_06_14_Batch6",
    # plate="BR00124787",
    # columns=["Metadata_Source", "Metadata_Plate", "Metadata_Well", "Cells_AreaShape_Eccentricity", "Nuclei_AreaShape_Area"],
    # output="input/raw_profiles_batch6.parquet",
)
# Out:
# 2023-04-05 11:33:41 INFO     Loading profiles from cellpainting-gallery/cpg0016-jump-fixed/source_4/workspace/profiles/2021_06_14_Batch6
# 2023-04-05 11:34:01 INFO     Found 17 files
# 2023-04-05 11:34:01 INFO     Load profiles...

# %% [markdown]
# ### Remove extra schema columns
#
# See https://github.com/broadinstitute/position-effect-correction/pull/4#discussion_r1158626931

# %%
profiles.drop(columns=['dataset', 'source', 'workspace', 'profiles', 'batch', 'plate'], inplace=True)
profiles.columns
# Out:
# Index(['Metadata_Source', 'Metadata_Plate', 'Metadata_Well',
#        'Cells_AreaShape_Area', 'Cells_AreaShape_BoundingBoxArea',
#        'Cells_AreaShape_BoundingBoxMaximum_X',
#        'Cells_AreaShape_BoundingBoxMaximum_Y',
#        'Cells_AreaShape_BoundingBoxMinimum_X',
#        'Cells_AreaShape_BoundingBoxMinimum_Y', 'Cells_AreaShape_Center_X',
#        ...
#        'Nuclei_Texture_Variance_RNA_10_02_256',
#        'Nuclei_Texture_Variance_RNA_10_03_256',
#        'Nuclei_Texture_Variance_RNA_3_00_256',
#        'Nuclei_Texture_Variance_RNA_3_01_256',
#        'Nuclei_Texture_Variance_RNA_3_02_256',
#        'Nuclei_Texture_Variance_RNA_3_03_256',
#        'Nuclei_Texture_Variance_RNA_5_00_256',
#        'Nuclei_Texture_Variance_RNA_5_01_256',
#        'Nuclei_Texture_Variance_RNA_5_02_256',
#        'Nuclei_Texture_Variance_RNA_5_03_256'],
#       dtype='object', length=4765)

# %% [markdown]
# ### Join features with metadata

# %%
metadata = orf.merge(wells, on="Metadata_JCP2022")
ann_dframe = metadata.merge(
    profiles, on=["Metadata_Source", "Metadata_Plate", "Metadata_Well"]
)
print(f"{ann_dframe.shape=}")
ann_dframe.groupby("Metadata_Plate")["Metadata_Well"].count()
# Out:
# ann_dframe.shape=(5500, 4777)
# Metadata_Plate
# BR00123945    364
# BR00124761    368
# BR00124766    364
# BR00124767    364
# BR00124768    364
# BR00124769    364
# BR00124770    368
# BR00124771    368
# BR00124772    368
# BR00124773    368
# BR00124775    368
# BR00124776    368
# BR00124777    368
# BR00124778    368
# BR00124779    368
# Name: Metadata_Well, dtype: int64

# %% [markdown]
# Print sample of rows from `ann_dframe` (only `Metadata_` columns)

# %%
ann_dframe.filter(regex="^Metadata_").sample(5)
# Out:
#      Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 2324   JCP2022_908893    ccsbBroad304_09532  ORF005554.1_TRC304.1
# 364    JCP2022_901313    ccsbBroad304_01402  ORF013020.1_TRC304.1
# 5134   JCP2022_915128    ccsbBroad304_99985  ORFC00001.1_TRC304.1
# 4947   JCP2022_914710    ccsbBroad304_15727  ORF005400.1_TRC304.1
# 542    JCP2022_901919    ccsbBroad304_02056  ORF016768.1_TRC304.1
#
#      Metadata_Vector Metadata_Transcript Metadata_Symbol  \
# 2324         pLX_304         NM_152393.4          KLHL40
# 364          pLX_304         NM_000326.5           RLBP1
# 5134         pLX_304               BFP.1             BFP
# 4947         pLX_304      NM_001191006.3          SRSF10
# 542          pLX_304         NM_004198.3          CHRNA6
#
#      Metadata_NCBI_Gene_ID Metadata_Taxon_ID  \
# 2324                131377              9606
# 364                   6017              9606
# 5134                   BFP           CONTROL
# 4947                 10772              9606
# 542                   8973              9606
#
#                            Metadata_Gene_Description  Metadata_Prot_Match  \
# 2324                     kelch like family member 40                 99.6
# 364                  retinaldehyde binding protein 1                100.0
# 5134                                    Hahn Lab BFP                 99.5
# 4947     serine and arginine rich splicing factor 10                100.0
# 542   cholinergic receptor nicotinic alpha 6 subunit                100.0
#
#       Metadata_Insert_Length Metadata_pert_type Metadata_Source  \
# 2324                  1863.0                trt        source_4
# 364                    951.0                trt        source_4
# 5134                   717.0             negcon        source_4
# 4947                   519.0                trt        source_4
# 542                   1482.0                trt        source_4
#
#      Metadata_Plate Metadata_Well
# 2324     BR00124777           B17
# 364      BR00124779           P14
# 5134     BR00124767           A01
# 4947     BR00124773           O02
# 542      BR00124775           G19

# %% [markdown]
# ## Save profiles

# %%
ann_dframe.to_parquet("output/metadata_profiles_batch6.parquet", index=False)

# %% [markdown]
# ## Subsample for testing

# %%
OVERLAP_PLATES = [
    "OAB84.85.86.87.A",
    "OAA97.98.99.XX.A",
    "OAB25.26.27.28.A",
    "OAB41.OAC17.OAB78.79.A",
    "OAA49.59.79.80.A",
    "OAA58.60.61.62.A",
    "OAA85.86.87.88.A",
    "OAB13.14.15.16.A",
    "OAB33.34.35.36.A",
    "OAB37.38.39.40.A",
]

# %%
profiles = pd.read_parquet("input/raw_profiles.parquet")
profiles
# Out:
#        Metadata_Source Metadata_Plate Metadata_Well  Cells_AreaShape_Area  \
# 0             source_4     BR00117035           A01           5834.000000
# 1             source_4     BR00117035           A02           5463.799805
# 2             source_4     BR00117035           A03           5416.000000
# 3             source_4     BR00117035           A04           5949.799805
# 4             source_4     BR00117035           A05           5820.700195
# ...                ...            ...           ...                   ...
# 106347        source_4     BR00127149           P20           3994.500000
# 106348        source_4     BR00127149           P21           3768.500000
# 106349        source_4     BR00127149           P22           3907.800049
# 106350        source_4     BR00127149           P23           3965.000000
# 106351        source_4     BR00127149           P24           4358.899902
#
#         Cells_AreaShape_BoundingBoxArea  Cells_AreaShape_BoundingBoxMaximum_X  \
# 0                          12214.000000                            569.679993
# 1                          11298.000000                            573.630005
# 2                          10838.000000                            602.969971
# 3                          12099.000000                            606.369995
# 4                          11727.000000                            574.479980
# ...                                 ...                                   ...
# 106347                      7444.100098                            585.150024
# 106348                      7743.100098                            574.130005
# 106349                      7337.000000                            558.799988
# 106350                      7350.500000                            591.299988
# 106351                      8109.399902                            566.099976
#
#         Cells_AreaShape_BoundingBoxMaximum_Y  \
# 0                                 552.330017
# 1                                 521.140015
# 2                                 526.530029
# 3                                 542.229980
# 4                                 538.989990
# ...                                      ...
# 106347                            593.719971
# 106348                            595.590027
# 106349                            587.570007
# 106350                            591.190002
# 106351                            603.309998
#
#         Cells_AreaShape_BoundingBoxMinimum_X  \
# 0                                 460.510010
# 1                                 469.579987
# 2                                 501.630005
# 3                                 498.839996
# 4                                 469.359985
# ...                                      ...
# 106347                            499.470001
# 106348                            484.209991
# 106349                            474.859985
# 106350                            506.019989
# 106351                            476.989990
#
#         Cells_AreaShape_BoundingBoxMinimum_Y  Cells_AreaShape_Center_X  ...  \
# 0                                 444.850006                515.229980  ...
# 1                                 416.619995                521.219971  ...
# 2                                 423.839996                551.570007  ...
# 3                                 433.579987                552.299988  ...
# 4                                 430.269989                521.330017  ...
# ...                                      ...                       ...  ...
# 106347                            508.179993                541.820007  ...
# 106348                            510.839996                528.650024  ...
# 106349                            502.049988                516.130005  ...
# 106350                            506.510010                548.289978  ...
# 106351                            513.359985                521.059998  ...
#
#         Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                                  34.516998
# 1                                  41.456001
# 2                                  43.127998
# 3                                  48.040001
# 4                                  37.455002
# ...                                      ...
# 106347                             48.408001
# 106348                             43.914001
# 106349                             46.410999
# 106350                             32.987000
# 106351                             17.382000
#
#         Nuclei_Texture_Variance_RNA_5_01_256  \
# 0                                  35.355000
# 1                                  42.639999
# 2                                  44.056000
# 3                                  49.353001
# 4                                  38.362000
# ...                                      ...
# 106347                             49.757999
# 106348                             44.806000
# 106349                             47.698002
# 106350                             33.810001
# 106351                             17.733000
#
#         Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                                  34.396000
# 1                                  41.368000
# 2                                  43.116001
# 3                                  47.851002
# 4                                  37.421001
# ...                                      ...
# 106347                             48.396000
# 106348                             43.602001
# 106349                             46.439999
# 106350                             33.090000
# 106351                             17.370001
#
#         Nuclei_Texture_Variance_RNA_5_03_256             dataset      source  \
# 0                                  35.499001   2021_04_26_Batch1  BR00117035
# 1                                  42.675999   2021_04_26_Batch1  BR00117035
# 2                                  44.318001   2021_04_26_Batch1  BR00117035
# 3                                  49.601002   2021_04_26_Batch1  BR00117035
# 4                                  38.554001   2021_04_26_Batch1  BR00117035
# ...                                      ...                 ...         ...
# 106347                             49.648998  2021_08_30_Batch13  BR00127149
# 106348                             45.058998  2021_08_30_Batch13  BR00127149
# 106349                             47.862000  2021_08_30_Batch13  BR00127149
# 106350                             33.995998  2021_08_30_Batch13  BR00127149
# 106351                             17.836000  2021_08_30_Batch13  BR00127149
#
#         workspace  profiles  batch  plate
# 0            None      None   None   None
# 1            None      None   None   None
# 2            None      None   None   None
# 3            None      None   None   None
# 4            None      None   None   None
# ...           ...       ...    ...    ...
# 106347       None      None   None   None
# 106348       None      None   None   None
# 106349       None      None   None   None
# 106350       None      None   None   None
# 106351       None      None   None   None
#
# [106352 rows x 4771 columns]

# %%
profiles = pd.read_parquet("input/raw_profiles.parquet")



ann_dframe = metadata.merge(
    profiles, on=["Metadata_Source", "Metadata_Plate", "Metadata_Well"]
)
print(f"{ann_dframe.shape=}")
ann_dframe
# Out:
# ann_dframe.shape=(86699, 4783)
#       Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0       JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 1       JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 2       JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 3       JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 4       JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# ...                ...                   ...                   ...
# 86694   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86695   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86696   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86697   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86698   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
#
#       Metadata_Vector Metadata_Transcript Metadata_Symbol  \
# 0             pLX_304      NM_001160173.3            NAT1
# 1             pLX_304      NM_001160173.3            NAT1
# 2             pLX_304      NM_001160173.3            NAT1
# 3             pLX_304      NM_001160173.3            NAT1
# 4             pLX_304      NM_001160173.3            NAT1
# ...               ...                 ...             ...
# 86694         pLX_304              eGFP.1            eGFP
# 86695         pLX_304              eGFP.1            eGFP
# 86696         pLX_304              eGFP.1            eGFP
# 86697         pLX_304              eGFP.1            eGFP
# 86698         pLX_304              eGFP.1            eGFP
#
#       Metadata_NCBI_Gene_ID Metadata_Taxon_ID Metadata_Gene_Description  \
# 0                         9              9606     N-acetyltransferase 1
# 1                         9              9606     N-acetyltransferase 1
# 2                         9              9606     N-acetyltransferase 1
# 3                         9              9606     N-acetyltransferase 1
# 4                         9              9606     N-acetyltransferase 1
# ...                     ...               ...                       ...
# 86694                  eGFP           CONTROL             Hahn Lab eGFP
# 86695                  eGFP           CONTROL             Hahn Lab eGFP
# 86696                  eGFP           CONTROL             Hahn Lab eGFP
# 86697                  eGFP           CONTROL             Hahn Lab eGFP
# 86698                  eGFP           CONTROL             Hahn Lab eGFP
#
#        Metadata_Prot_Match  ...  Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                    100.0  ...                             78.186996
# 1                    100.0  ...                             68.393997
# 2                    100.0  ...                             85.594002
# 3                    100.0  ...                             67.583000
# 4                    100.0  ...                             59.471001
# ...                    ...  ...                                   ...
# 86694                100.0  ...                             48.321999
# 86695                100.0  ...                             62.254002
# 86696                100.0  ...                             54.183998
# 86697                100.0  ...                             49.897999
# 86698                100.0  ...                             47.036999
#
#       Nuclei_Texture_Variance_RNA_5_01_256  \
# 0                                80.055000
# 1                                70.334999
# 2                                88.263000
# 3                                69.570000
# 4                                61.160000
# ...                                    ...
# 86694                            49.332001
# 86695                            63.467999
# 86696                            55.118999
# 86697                            51.120998
# 86698                            48.039001
#
#       Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                                77.632004
# 1                                68.253998
# 2                                85.778000
# 3                                67.693001
# 4                                59.660000
# ...                                    ...
# 86694                            48.254002
# 86695                            62.254002
# 86696                            54.115002
# 86697                            49.785999
# 86698                            46.994999
#
#       Nuclei_Texture_Variance_RNA_5_03_256             dataset      source  \
# 0                                79.955002   2021_06_21_Batch7  BR00125170
# 1                                70.283997   2021_06_21_Batch7  BR00125171
# 2                                88.174004   2021_06_21_Batch7  BR00125172
# 3                                69.511002   2021_06_21_Batch7  BR00125173
# 4                                61.311001   2021_06_21_Batch7  BR00125174
# ...                                    ...                 ...         ...
# 86694                            49.356998  2021_08_23_Batch12  BR00126718
# 86695                            63.646000  2021_08_23_Batch12  BR00126718
# 86696                            55.305000  2021_08_23_Batch12  BR00126718
# 86697                            50.945999  2021_08_23_Batch12  BR00126718
# 86698                            48.241001  2021_08_23_Batch12  BR00126718
#
#        workspace  profiles  batch  plate
# 0           None      None   None   None
# 1           None      None   None   None
# 2           None      None   None   None
# 3           None      None   None   None
# 4           None      None   None   None
# ...          ...       ...    ...    ...
# 86694       None      None   None   None
# 86695       None      None   None   None
# 86696       None      None   None   None
# 86697       None      None   None   None
# 86698       None      None   None   None
#
# [86699 rows x 4783 columns]

# %%
profiles.columns
# Out:
# Index(['Metadata_Source', 'Metadata_Plate', 'Metadata_Well',
#        'Cells_AreaShape_Area', 'Cells_AreaShape_BoundingBoxArea',
#        'Cells_AreaShape_BoundingBoxMaximum_X',
#        'Cells_AreaShape_BoundingBoxMaximum_Y',
#        'Cells_AreaShape_BoundingBoxMinimum_X',
#        'Cells_AreaShape_BoundingBoxMinimum_Y', 'Cells_AreaShape_Center_X',
#        ...
#        'Nuclei_Texture_Variance_RNA_5_00_256',
#        'Nuclei_Texture_Variance_RNA_5_01_256',
#        'Nuclei_Texture_Variance_RNA_5_02_256',
#        'Nuclei_Texture_Variance_RNA_5_03_256', 'dataset', 'source',
#        'workspace', 'profiles', 'batch', 'plate'],
#       dtype='object', length=4771)

# %%
import glob

# pull from https://github.com/jump-cellpainting/jump-orf-data/tree/master/metadata/platemaps
platemaps = glob.glob("../../jump-orf-data/metadata/platemaps/*/*.csv")
platemaps = pd.concat((pd.read_csv(f) for f in platemaps), ignore_index=True)
assert ~platemaps.duplicated().any()

platemaps.columns = ["Metadata_Plate", "Metadata_Plate_Map_Name"]
platemaps
# Out:
#     Metadata_Plate          Metadata_Plate_Map_Name
# 0       BR00126544                          control
# 1       BR00121426  JUMP-Target-2_compound_platemap
# 2       BR00126542                 OAB37.38.39.40.A
# 3       BR00126541                 OAB37.38.39.40.A
# 4       BR00126540                 OAB37.38.39.40.A
# ..             ...                              ...
# 272     BR00123627              OAA41.42.43.OAB45.A
# 273     BR00123628              OAA41.42.43.OAB45.A
# 274     BR00123629              OAA41.42.43.OAB45.A
# 275     BR00123621              OAA41.42.43.OAB45.A
# 276     BR00123622              OAA41.42.43.OAB45.A
#
# [277 rows x 2 columns]

# %%
ann_dframe = ann_dframe.merge(platemaps, on="Metadata_Plate")
ann_dframe
# Out:
#       Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0       JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 1       JCP2022_900011    ccsbBroad304_00013  ORF009063.1_TRC304.1
# 2       JCP2022_900033    ccsbBroad304_00037  ORF015627.1_TRC304.1
# 3       JCP2022_900063    ccsbBroad304_00069  ORF005433.1_TRC304.1
# 4       JCP2022_900084    ccsbBroad304_00091  ORF014376.1_TRC304.1
# ...                ...                   ...                   ...
# 86694   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86695   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86696   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86697   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86698   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
#
#       Metadata_Vector Metadata_Transcript Metadata_Symbol  \
# 0             pLX_304      NM_001160173.3            NAT1
# 1             pLX_304         NM_001612.6           ACRV1
# 2             pLX_304         NM_001136.5            AGER
# 3             pLX_304         NM_001153.5           ANXA4
# 4             pLX_304         NM_001651.4            AQP5
# ...               ...                 ...             ...
# 86694         pLX_304              eGFP.1            eGFP
# 86695         pLX_304              eGFP.1            eGFP
# 86696         pLX_304              eGFP.1            eGFP
# 86697         pLX_304              eGFP.1            eGFP
# 86698         pLX_304              eGFP.1            eGFP
#
#       Metadata_NCBI_Gene_ID Metadata_Taxon_ID  \
# 0                         9              9606
# 1                        56              9606
# 2                       177              9606
# 3                       307              9606
# 4                       362              9606
# ...                     ...               ...
# 86694                  eGFP           CONTROL
# 86695                  eGFP           CONTROL
# 86696                  eGFP           CONTROL
# 86697                  eGFP           CONTROL
# 86698                  eGFP           CONTROL
#
#                                Metadata_Gene_Description  Metadata_Prot_Match  \
# 0                                  N-acetyltransferase 1                100.0
# 1                            acrosomal vesicle protein 1                100.0
# 2      advanced glycosylation end-product specific re...                100.0
# 3                                             annexin A4                100.0
# 4                                            aquaporin 5                100.0
# ...                                                  ...                  ...
# 86694                                      Hahn Lab eGFP                100.0
# 86695                                      Hahn Lab eGFP                100.0
# 86696                                      Hahn Lab eGFP                100.0
# 86697                                      Hahn Lab eGFP                100.0
# 86698                                      Hahn Lab eGFP                100.0
#
#        ...  Nuclei_Texture_Variance_RNA_5_01_256  \
# 0      ...                             80.055000
# 1      ...                             92.719002
# 2      ...                            131.880005
# 3      ...                             85.179001
# 4      ...                             90.223000
# ...    ...                                   ...
# 86694  ...                             44.397999
# 86695  ...                             46.152000
# 86696  ...                             33.742001
# 86697  ...                             40.847000
# 86698  ...                             35.081001
#
#       Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                                77.632004
# 1                                89.843002
# 2                               127.940002
# 3                                82.646004
# 4                                87.663002
# ...                                    ...
# 86694                            43.558998
# 86695                            45.151001
# 86696                            32.956001
# 86697                            40.073002
# 86698                            34.152000
#
#       Nuclei_Texture_Variance_RNA_5_03_256             dataset      source  \
# 0                                79.955002   2021_06_21_Batch7  BR00125170
# 1                                92.597000   2021_06_21_Batch7  BR00125170
# 2                               131.960007   2021_06_21_Batch7  BR00125170
# 3                                85.292999   2021_06_21_Batch7  BR00125170
# 4                                90.227997   2021_06_21_Batch7  BR00125170
# ...                                    ...                 ...         ...
# 86694                            44.814999  2021_08_23_Batch12  BR00126714
# 86695                            46.422001  2021_08_23_Batch12  BR00126714
# 86696                            33.784000  2021_08_23_Batch12  BR00126714
# 86697                            40.930000  2021_08_23_Batch12  BR00126714
# 86698                            35.153999  2021_08_23_Batch12  BR00126714
#
#        workspace  profiles  batch  plate  Metadata_Plate_Map_Name
# 0           None      None   None   None         OAB09.10.11.12.A
# 1           None      None   None   None         OAB09.10.11.12.A
# 2           None      None   None   None         OAB09.10.11.12.A
# 3           None      None   None   None         OAB09.10.11.12.A
# 4           None      None   None   None         OAB09.10.11.12.A
# ...          ...       ...    ...    ...                      ...
# 86694       None      None   None   None         OKA01.02.03.04.A
# 86695       None      None   None   None         OKA01.02.03.04.A
# 86696       None      None   None   None         OKA01.02.03.04.A
# 86697       None      None   None   None         OKA01.02.03.04.A
# 86698       None      None   None   None         OKA01.02.03.04.A
#
# [86699 rows x 4784 columns]

# %%
# check JCP overlap between plates, https://github.com/jump-cellpainting/jump-cellpainting/issues/78#issuecomment-805942281

overlap = list(set(ann_dframe.loc[ann_dframe["Metadata_Plate_Map_Name"] == 'OKA05.06.07.08.A', "Metadata_JCP2022"].unique()).intersection(
    set(ann_dframe.loc[ann_dframe["Metadata_Plate_Map_Name"] == 'OAB84.85.86.87.A', "Metadata_JCP2022"].unique())
))
print(f"{overlap=}")

ann_dframe.loc[ann_dframe["Metadata_JCP2022"].isin(overlap)]
# Out:
# overlap=['JCP2022_915131', 'JCP2022_915128', 'JCP2022_901127', 'JCP2022_908011', 'JCP2022_900475', 'JCP2022_900001', 'JCP2022_910867', 'JCP2022_912974', 'JCP2022_906380', 'JCP2022_915130', 'JCP2022_915129', 'JCP2022_912981', 'JCP2022_915132']
#       Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 340     JCP2022_900001         BAD CONSTRUCT         BAD CONSTRUCT
# 341     JCP2022_900001         BAD CONSTRUCT         BAD CONSTRUCT
# 342     JCP2022_900001         BAD CONSTRUCT         BAD CONSTRUCT
# 343     JCP2022_900001         BAD CONSTRUCT         BAD CONSTRUCT
# 344     JCP2022_915128    ccsbBroad304_99985  ORFC00001.1_TRC304.1
# ...                ...                   ...                   ...
# 86694   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86695   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86696   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86697   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 86698   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
#
#       Metadata_Vector Metadata_Transcript Metadata_Symbol  \
# 340           pLX_304                 NaN             NaN
# 341           pLX_304                 NaN             NaN
# 342           pLX_304                 NaN             NaN
# 343           pLX_304                 NaN             NaN
# 344           pLX_304               BFP.1             BFP
# ...               ...                 ...             ...
# 86694         pLX_304              eGFP.1            eGFP
# 86695         pLX_304              eGFP.1            eGFP
# 86696         pLX_304              eGFP.1            eGFP
# 86697         pLX_304              eGFP.1            eGFP
# 86698         pLX_304              eGFP.1            eGFP
#
#       Metadata_NCBI_Gene_ID Metadata_Taxon_ID Metadata_Gene_Description  \
# 340                     NaN               NaN                       NaN
# 341                     NaN               NaN                       NaN
# 342                     NaN               NaN                       NaN
# 343                     NaN               NaN                       NaN
# 344                     BFP           CONTROL              Hahn Lab BFP
# ...                     ...               ...                       ...
# 86694                  eGFP           CONTROL             Hahn Lab eGFP
# 86695                  eGFP           CONTROL             Hahn Lab eGFP
# 86696                  eGFP           CONTROL             Hahn Lab eGFP
# 86697                  eGFP           CONTROL             Hahn Lab eGFP
# 86698                  eGFP           CONTROL             Hahn Lab eGFP
#
#        Metadata_Prot_Match  ...  Nuclei_Texture_Variance_RNA_5_01_256  \
# 340                    NaN  ...                             78.267998
# 341                    NaN  ...                             86.281998
# 342                    NaN  ...                            104.739998
# 343                    NaN  ...                            145.500000
# 344                   99.5  ...                             63.132999
# ...                    ...  ...                                   ...
# 86694                100.0  ...                             44.397999
# 86695                100.0  ...                             46.152000
# 86696                100.0  ...                             33.742001
# 86697                100.0  ...                             40.847000
# 86698                100.0  ...                             35.081001
#
#       Nuclei_Texture_Variance_RNA_5_02_256  \
# 340                              75.882004
# 341                              83.939003
# 342                             102.239998
# 343                             140.309998
# 344                              61.470001
# ...                                    ...
# 86694                            43.558998
# 86695                            45.151001
# 86696                            32.956001
# 86697                            40.073002
# 86698                            34.152000
#
#       Nuclei_Texture_Variance_RNA_5_03_256             dataset      source  \
# 340                              78.258003   2021_06_21_Batch7  BR00125170
# 341                              85.920998   2021_06_21_Batch7  BR00125170
# 342                             104.930000   2021_06_21_Batch7  BR00125170
# 343                             144.050003   2021_06_21_Batch7  BR00125170
# 344                              63.311001   2021_06_21_Batch7  BR00125170
# ...                                    ...                 ...         ...
# 86694                            44.814999  2021_08_23_Batch12  BR00126714
# 86695                            46.422001  2021_08_23_Batch12  BR00126714
# 86696                            33.784000  2021_08_23_Batch12  BR00126714
# 86697                            40.930000  2021_08_23_Batch12  BR00126714
# 86698                            35.153999  2021_08_23_Batch12  BR00126714
#
#        workspace  profiles  batch  plate  Metadata_Plate_Map_Name
# 340         None      None   None   None         OAB09.10.11.12.A
# 341         None      None   None   None         OAB09.10.11.12.A
# 342         None      None   None   None         OAB09.10.11.12.A
# 343         None      None   None   None         OAB09.10.11.12.A
# 344         None      None   None   None         OAB09.10.11.12.A
# ...          ...       ...    ...    ...                      ...
# 86694       None      None   None   None         OKA01.02.03.04.A
# 86695       None      None   None   None         OKA01.02.03.04.A
# 86696       None      None   None   None         OKA01.02.03.04.A
# 86697       None      None   None   None         OKA01.02.03.04.A
# 86698       None      None   None   None         OKA01.02.03.04.A
#
# [6620 rows x 4784 columns]

# %%
# anti join `Metadata_JCP2022` to get the rows in `wells` that are not in `orf`
wells[~wells.Metadata_JCP2022.isin(orf.Metadata_JCP2022)]
# Out:
#        Metadata_Source     Metadata_Plate Metadata_Well Metadata_JCP2022
# 0            source_10  Dest210531-152149           A01   JCP2022_085227
# 1            source_10  Dest210531-152149           A02   JCP2022_033924
# 2            source_10  Dest210531-152149           A03   JCP2022_056163
# 3            source_10  Dest210531-152149           A04   JCP2022_054175
# 4            source_10  Dest210531-152149           A05   JCP2022_999999
# ...                ...                ...           ...              ...
# 586613        source_8           A1170544           P20   JCP2022_041390
# 586614        source_8           A1170544           P21   JCP2022_999999
# 586615        source_8           A1170544           P22   JCP2022_024363
# 586616        source_8           A1170544           P23   JCP2022_033924
# 586617        source_8           A1170544           P24   JCP2022_046054
#
# [499919 rows x 4 columns]
