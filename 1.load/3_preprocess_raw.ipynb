# %% [markdown]
# ## Normalize and select CP features using Pycytominer

# %%
import pandas as pd
from preprocess import preprocess_profiles

# %%
profiles = pd.read_parquet("output/raw_filtered_profiles.parquet")
profiles.head()
# Out:
#   Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0   JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 1   JCP2022_900011    ccsbBroad304_00013  ORF009063.1_TRC304.1
# 2   JCP2022_900033    ccsbBroad304_00037  ORF015627.1_TRC304.1
# 3   JCP2022_900063    ccsbBroad304_00069  ORF005433.1_TRC304.1
# 4   JCP2022_900084    ccsbBroad304_00091  ORF014376.1_TRC304.1
#
#   Metadata_Vector Metadata_Transcript Metadata_Symbol Metadata_NCBI_Gene_ID  \
# 0         pLX_304      NM_001160173.3            NAT1                     9
# 1         pLX_304         NM_001612.6           ACRV1                    56
# 2         pLX_304         NM_001136.5            AGER                   177
# 3         pLX_304         NM_001153.5           ANXA4                   307
# 4         pLX_304         NM_001651.4            AQP5                   362
#
#   Metadata_Taxon_ID                          Metadata_Gene_Description  \
# 0              9606                              N-acetyltransferase 1
# 1              9606                        acrosomal vesicle protein 1
# 2              9606  advanced glycosylation end-product specific re...
# 3              9606                                         annexin A4
# 4              9606                                        aquaporin 5
#
#    Metadata_Prot_Match  ...  Nuclei_Texture_Variance_RNA_10_02_256  \
# 0                100.0  ...                              82.535004
# 1                100.0  ...                              95.772003
# 2                100.0  ...                             135.899994
# 3                100.0  ...                              88.174004
# 4                100.0  ...                              94.418999
#
#   Nuclei_Texture_Variance_RNA_10_03_256 Nuclei_Texture_Variance_RNA_3_00_256  \
# 0                             82.875999                            76.996002
# 1                             93.607002                            88.196999
# 2                            133.380005                           126.150002
# 3                             84.871002                            80.910004
# 4                             91.669998                            87.241997
#
#   Nuclei_Texture_Variance_RNA_3_01_256 Nuclei_Texture_Variance_RNA_3_02_256  \
# 0                            77.473999                            76.582001
# 1                            89.211998                            88.081001
# 2                           127.250000                           125.769997
# 3                            81.814003                            80.850998
# 4                            87.132004                            86.538002
#
#   Nuclei_Texture_Variance_RNA_3_03_256  Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                            77.233002                             78.186996
# 1                            89.154999                             89.897003
# 2                           127.250000                            128.429993
# 3                            81.926003                             82.567001
# 4                            87.476997                             88.224998
#
#   Nuclei_Texture_Variance_RNA_5_01_256  Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                            80.055000                             77.632004
# 1                            92.719002                             89.843002
# 2                           131.880005                            127.940002
# 3                            85.179001                             82.646004
# 4                            90.223000                             87.663002
#
#    Nuclei_Texture_Variance_RNA_5_03_256
# 0                             79.955002
# 1                             92.597000
# 2                            131.960007
# 3                             85.292999
# 4                             90.227997
#
# [5 rows x 4780 columns]

# %%
profiles.shape
# Out:
# (83869, 4780)

# %% [markdown]
# ##### Run feature normalization with `RobustMAD`, followed by feature selection and `NaN` removal

# %%
profiles = preprocess_profiles(profiles)
profiles.head()
# Out:
#   Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0   JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 1   JCP2022_900011    ccsbBroad304_00013  ORF009063.1_TRC304.1
# 2   JCP2022_900033    ccsbBroad304_00037  ORF015627.1_TRC304.1
# 3   JCP2022_900063    ccsbBroad304_00069  ORF005433.1_TRC304.1
# 4   JCP2022_900084    ccsbBroad304_00091  ORF014376.1_TRC304.1
#
#   Metadata_Vector Metadata_Transcript Metadata_Symbol Metadata_NCBI_Gene_ID  \
# 0         pLX_304      NM_001160173.3            NAT1                     9
# 1         pLX_304         NM_001612.6           ACRV1                    56
# 2         pLX_304         NM_001136.5            AGER                   177
# 3         pLX_304         NM_001153.5           ANXA4                   307
# 4         pLX_304         NM_001651.4            AQP5                   362
#
#   Metadata_Taxon_ID                          Metadata_Gene_Description  \
# 0              9606                              N-acetyltransferase 1
# 1              9606                        acrosomal vesicle protein 1
# 2              9606  advanced glycosylation end-product specific re...
# 3              9606                                         annexin A4
# 4              9606                                        aquaporin 5
#
#    Metadata_Prot_Match  ...  Nuclei_Texture_Correlation_Mito_10_01_256  \
# 0                100.0  ...                                  -0.244817
# 1                100.0  ...                                  -1.521598
# 2                100.0  ...                                  -0.379910
# 3                100.0  ...                                  -1.049128
# 4                100.0  ...                                  -0.678034
#
#   Nuclei_Texture_Correlation_Mito_10_02_256  \
# 0                                  0.583327
# 1                                 -0.791275
# 2                                  0.546385
# 3                                 -0.039326
# 4                                 -0.175177
#
#   Nuclei_Texture_Correlation_Mito_10_03_256  \
# 0                                 -0.384875
# 1                                 -0.702115
# 2                                 -0.258182
# 3                                 -0.663357
# 4                                  1.352978
#
#   Nuclei_Texture_Correlation_Mito_5_03_256  \
# 0                                 0.343745
# 1                                 0.687040
# 2                                 0.960870
# 3                                 0.036301
# 4                                 0.668217
#
#   Nuclei_Texture_Correlation_RNA_3_00_256  \
# 0                                0.329153
# 1                               -0.298462
# 2                               -1.014771
# 3                               -0.331850
# 4                                2.129033
#
#   Nuclei_Texture_InfoMeas1_AGP_3_00_256 Nuclei_Texture_InfoMeas1_DNA_3_00_256  \
# 0                              0.077150                              0.085613
# 1                              1.368079                              0.424593
# 2                              0.433111                              0.360384
# 3                              0.169578                              0.386414
# 4                             -0.283393                              0.380630
#
#    Nuclei_Texture_InfoMeas1_ER_3_00_256  \
# 0                              0.130721
# 1                             -0.122986
# 2                             -0.277686
# 3                              0.061880
# 4                             -0.145418
#
#    Nuclei_Texture_InfoMeas1_Mito_3_00_256  \
# 0                                0.272240
# 1                                0.445006
# 2                               -0.128267
# 3                                0.258278
# 4                               -0.296671
#
#    Nuclei_Texture_InfoMeas1_RNA_10_02_256
# 0                               -0.095430
# 1                               -0.504311
# 2                               -1.196742
# 3                               -0.426073
# 4                               -0.202322
#
# [5 rows x 539 columns]

# %% [markdown]
# Save preprocessed profiles

# %%
profiles.to_parquet("output/full_processed_profiles.parquet")
