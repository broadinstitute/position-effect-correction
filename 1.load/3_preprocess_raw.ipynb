# %% [markdown]
# ## Normalize and select CP features using Pycytominer

# %%
import sys

sys.path.append("../scripts")

import pandas as pd

from load import load_config
from preprocess import preprocess_profiles

# %%
preprocess_config = load_config("../configs/preprocess")
preprocess_config
# Out:
# {'normalize_group': 'Metadata_Plate',
#  'normalize_kwargs': {'method': 'mad_robustize',
#   'mad_robustize_epsilon': 0.0,
#   'image_features': True},
#  'feature_select_whitelist': ['Cells_Count'],
#  'feature_select_kwargs': {'operation': ['variance_threshold',
#    'correlation_threshold',
#    'drop_na_columns',
#    'blocklist'],
#   'unique_cut': 0.01,
#   'image_features': True}}

# %%
ann_df = pd.read_parquet("output/raw_filtered_profiles.parquet")
ann_df
# Out:
#       Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0       JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 1       JCP2022_900011    ccsbBroad304_00013  ORF009063.1_TRC304.1
# 2       JCP2022_900033    ccsbBroad304_00037  ORF015627.1_TRC304.1
# 3       JCP2022_900063    ccsbBroad304_00069  ORF005433.1_TRC304.1
# 4       JCP2022_900084    ccsbBroad304_00091  ORF014376.1_TRC304.1
# ...                ...                   ...                   ...
# 79555   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 79556   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 79557   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 79558   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 79559   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
#
#       Metadata_Vector Metadata_Transcript Metadata_Symbol  \
# 0             pLX_304      NM_001160173.3            NAT1
# ...

# %% [markdown]
# ##### Run feature normalization with `RobustMAD`, followed by feature selection and `NaN` removal

# %%
# %%time
ann_df = preprocess_profiles(ann_df, **preprocess_config)
ann_df
# Out:
# CPU times: user 49min 47s, sys: 23.5 s, total: 50min 10s
# Wall time: 51min 34s
#       Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0       JCP2022_900257    ccsbBroad304_00280  ORF012864.1_TRC304.1
# 1       JCP2022_900258    ccsbBroad304_00281  ORF011987.1_TRC304.1
# 2       JCP2022_900264    ccsbBroad304_00287  ORF008900.1_TRC304.1
# 3       JCP2022_900266    ccsbBroad304_00289  ORF011627.1_TRC304.1
# 4       JCP2022_900267    ccsbBroad304_00290  ORF016845.1_TRC304.1
# ...                ...                   ...                   ...
# 78270   JCP2022_915130    ccsbBroad304_99991  ORFC00003.1_TRC304.1
# 78271   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 78272   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 78273   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 78274   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
#
#       Metadata_Vector Metadata_Transcript Metadata_Symbol  \
# ...

# %% [markdown]
# #### Save preprocessed profiles

# %%
ann_df.to_parquet("output/full_processed_profiles.parquet", index=False)
