# %% [markdown]
# ## Remove unused columns, rows with missing info, etc.

# %%
import sys

sys.path.append("../scripts")

import pandas as pd
from matplotlib import pyplot as plt

from load import load_config, merge_metadata
from plot_utils import plot_unique_value_hist
from preprocess import drop_na_feature_rows

# %% [markdown]
# #### Read and merge metadata

# %%
metadata_configs = load_config("../configs/metadata_with_poscon")
metadata_configs.keys()
# Out:
# dict_keys(['well', 'profile', 'platemap', 'cell_count', 'orf'])

# %%
ann_df = merge_metadata(metadata_configs)
ann_df
# Out:
#       Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0       JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 1       JCP2022_900011    ccsbBroad304_00013  ORF009063.1_TRC304.1
# 2       JCP2022_900033    ccsbBroad304_00037  ORF015627.1_TRC304.1
# 3       JCP2022_900063    ccsbBroad304_00069  ORF005433.1_TRC304.1
# 4       JCP2022_900084    ccsbBroad304_00091  ORF014376.1_TRC304.1
# ...                ...                   ...                   ...
# 81488   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 81489   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 81490   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 81491   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 81492   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
#
#       Metadata_Vector Metadata_Transcript Metadata_Symbol  \
# 0             pLX_304      NM_001160173.3            NAT1
# 1             pLX_304         NM_001612.6           ACRV1
# 2             pLX_304         NM_001136.5            AGER
# 3             pLX_304         NM_001153.5           ANXA4
# 4             pLX_304         NM_001651.4            AQP5
# ...               ...                 ...             ...
# 81488         pLX_304              eGFP.1            eGFP
# 81489         pLX_304              eGFP.1            eGFP
# 81490         pLX_304              eGFP.1            eGFP
# 81491         pLX_304              eGFP.1            eGFP
# 81492         pLX_304              eGFP.1            eGFP
#
#       Metadata_NCBI_Gene_ID Metadata_Taxon_ID  \
# 0                         9              9606
# 1                        56              9606
# 2                       177              9606
# 3                       307              9606
# 4                       362              9606
# ...                     ...               ...
# 81488                  eGFP           CONTROL
# 81489                  eGFP           CONTROL
# 81490                  eGFP           CONTROL
# 81491                  eGFP           CONTROL
# 81492                  eGFP           CONTROL
#
#                                Metadata_Gene_Description  Metadata_Prot_Match  \
# 0                                  N-acetyltransferase 1                100.0
# 1                            acrosomal vesicle protein 1                100.0
# 2      advanced glycosylation end-product specific re...                100.0
# 3                                             annexin A4                100.0
# 4                                            aquaporin 5                100.0
# ...                                                  ...                  ...
# 81488                                      Hahn Lab eGFP                100.0
# 81489                                      Hahn Lab eGFP                100.0
# 81490                                      Hahn Lab eGFP                100.0
# 81491                                      Hahn Lab eGFP                100.0
# 81492                                      Hahn Lab eGFP                100.0
#
#        ...  Nuclei_Texture_Variance_RNA_10_03_256  \
# 0      ...                              82.875999
# 1      ...                              93.607002
# 2      ...                             133.380005
# 3      ...                              84.871002
# 4      ...                              91.669998
# ...    ...                                    ...
# 81488  ...                              55.507999
# 81489  ...                              82.763000
# 81490  ...                              80.323997
# 81491  ...                              64.931999
# 81492  ...                              57.710999
#
#       Nuclei_Texture_Variance_RNA_3_00_256  \
# 0                                76.996002
# 1                                88.196999
# 2                               126.150002
# 3                                80.910004
# 4                                87.241997
# ...                                    ...
# 81488                            52.641998
# 81489                            78.248001
# 81490                            75.813004
# 81491                            60.368000
# 81492                            54.028999
#
#       Nuclei_Texture_Variance_RNA_3_01_256  \
# 0                                77.473999
# 1                                89.211998
# 2                               127.250000
# 3                                81.814003
# 4                                87.132004
# ...                                    ...
# 81488                            52.819000
# 81489                            78.682999
# 81490                            75.680000
# 81491                            60.714001
# 81492                            54.479000
#
#       Nuclei_Texture_Variance_RNA_3_02_256  \
# 0                                76.582001
# 1                                88.081001
# 2                               125.769997
# 3                                80.850998
# 4                                86.538002
# ...                                    ...
# 81488                            52.685001
# 81489                            78.156998
# 81490                            75.359001
# 81491                            60.174999
# 81492                            54.161999
#
#       Nuclei_Texture_Variance_RNA_3_03_256  \
# 0                                77.233002
# 1                                89.154999
# 2                               127.250000
# 3                                81.926003
# 4                                87.476997
# ...                                    ...
# 81488                            52.908001
# 81489                            78.873001
# 81490                            75.810997
# 81491                            60.575001
# 81492                            54.435001
#
#       Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                                78.186996
# 1                                89.897003
# 2                               128.429993
# 3                                82.567001
# 4                                88.224998
# ...                                    ...
# 81488                            53.057999
# 81489                            79.271004
# 81490                            76.195000
# 81491                            60.935001
# 81492                            54.666000
#
#        Nuclei_Texture_Variance_RNA_5_01_256  \
# 0                                 80.055000
# 1                                 92.719002
# 2                                131.880005
# 3                                 85.179001
# 4                                 90.223000
# ...                                     ...
# 81488                             54.457001
# 81489                             81.320000
# 81490                             77.635002
# 81491                             62.526001
# 81492                             56.235001
#
#        Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                                 77.632004
# 1                                 89.843002
# 2                                127.940002
# 3                                 82.646004
# 4                                 87.663002
# ...                                     ...
# 81488                             53.095001
# 81489                             79.264000
# 81490                             75.720001
# 81491                             60.872002
# 81492                             54.730000
#
#        Nuclei_Texture_Variance_RNA_5_03_256      Metadata_Batch
# 0                                 79.955002   2021_06_21_Batch7
# 1                                 92.597000   2021_06_21_Batch7
# 2                                131.960007   2021_06_21_Batch7
# 3                                 85.292999   2021_06_21_Batch7
# 4                                 90.227997   2021_06_21_Batch7
# ...                                     ...                 ...
# 81488                             54.158001  2021_08_30_Batch13
# 81489                             81.386002  2021_08_30_Batch13
# 81490                             77.588997  2021_08_30_Batch13
# 81491                             62.504002  2021_08_30_Batch13
# 81492                             56.094002  2021_08_30_Batch13
#
# [81493 rows x 4780 columns]

# %% [markdown]
# #### Visualize ratio of num unique values to data size
#
# Experiments showed that even after adding cell pcounts as a feature, it typically is filtered out later by pycytominer's `feature_select`.
#
# The reason for that is relatively low number of unique values.

# %%
plot_unique_value_hist(ann_df, unique_ratio_cutoff=0.1, features="Cells_Count")

# %% [markdown]
# #### List metadata stats

# %%
ann_df.filter(regex="^Metadata_").nunique()
# Out:
# Metadata_JCP2022             15097
# Metadata_broad_sample        15097
# Metadata_Name                15097
# Metadata_Vector                  1
# Metadata_Transcript          13553
# Metadata_Symbol              12602
# Metadata_NCBI_Gene_ID        12602
# Metadata_Taxon_ID                2
# Metadata_Gene_Description    12452
# Metadata_Prot_Match            904
# Metadata_Insert_Length        1667
# Metadata_pert_type               3
# Metadata_Source                  1
# Metadata_Plate                 225
# Metadata_Well                  376
# Metadata_plate_map_name         45
# Metadata_Batch                  12
# dtype: int64

# %% [markdown]
# #### Remove rows with NaNs in features

# %%
ann_df[ann_df.filter(regex="^(?!Metadata_)").isnull().T.any()]
# Out:
#       Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 4115    JCP2022_904659    ccsbBroad304_04978  ORF007315.1_TRC304.1
# 14324   JCP2022_905289    ccsbBroad304_05656  ORF006401.1_TRC304.1
# 58935   JCP2022_913113    ccsbBroad304_14055  ORF013056.1_TRC304.1
#
#       Metadata_Vector Metadata_Transcript Metadata_Symbol  \
# 4115          pLX_304         NM_178232.4          HAPLN3
# 14324         pLX_304         NM_207118.3          GTF2H5
# 58935         pLX_304      NM_001306195.1          ARPP19
#
#       Metadata_NCBI_Gene_ID Metadata_Taxon_ID  \
# 4115                 145864              9606
# 14324                404672              9606
# 58935                 10776              9606
#
#                         Metadata_Gene_Description  Metadata_Prot_Match  ...  \
# 4115   hyaluronan and proteoglycan link protein 3                100.0  ...
# 14324  general transcription factor IIH subunit 5                100.0  ...
# 58935            cAMP regulated phosphoprotein 19                 99.1  ...
#
#        Nuclei_Texture_Variance_RNA_10_03_256  \
# 4115                               64.606003
# 14324                              58.566002
# 58935                             121.300003
#
#       Nuclei_Texture_Variance_RNA_3_00_256  \
# 4115                             60.101002
# 14324                            56.141998
# 58935                           114.349998
#
#       Nuclei_Texture_Variance_RNA_3_01_256  \
# 4115                             60.910999
# 14324                            56.303001
# 58935                           115.099998
#
#       Nuclei_Texture_Variance_RNA_3_02_256  \
# 4115                             60.292000
# 14324                            56.070999
# 58935                           114.349998
#
#       Nuclei_Texture_Variance_RNA_3_03_256  \
# 4115                             60.720001
# 14324                            56.668999
# 58935                           115.180000
#
#       Nuclei_Texture_Variance_RNA_5_00_256  \
# 4115                             61.242001
# 14324                            56.942001
# 58935                           115.989998
#
#        Nuclei_Texture_Variance_RNA_5_01_256  \
# 4115                              63.160000
# 14324                             58.181999
# 58935                            119.370003
#
#        Nuclei_Texture_Variance_RNA_5_02_256  \
# 4115                              61.384998
# 14324                             56.842999
# 58935                            116.120003
#
#        Nuclei_Texture_Variance_RNA_5_03_256      Metadata_Batch
# 4115                              63.092999   2021_07_12_Batch8
# 14324                             58.549999   2021_07_12_Batch8
# 58935                            119.330002  2021_08_02_Batch10
#
# [3 rows x 4780 columns]

# %%
ann_df = drop_na_feature_rows(ann_df)
ann_df
# Out:
#       Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0       JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 1       JCP2022_900011    ccsbBroad304_00013  ORF009063.1_TRC304.1
# 2       JCP2022_900033    ccsbBroad304_00037  ORF015627.1_TRC304.1
# 3       JCP2022_900063    ccsbBroad304_00069  ORF005433.1_TRC304.1
# 4       JCP2022_900084    ccsbBroad304_00091  ORF014376.1_TRC304.1
# ...                ...                   ...                   ...
# 81485   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 81486   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 81487   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 81488   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 81489   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
#
#       Metadata_Vector Metadata_Transcript Metadata_Symbol  \
# 0             pLX_304      NM_001160173.3            NAT1
# 1             pLX_304         NM_001612.6           ACRV1
# 2             pLX_304         NM_001136.5            AGER
# 3             pLX_304         NM_001153.5           ANXA4
# 4             pLX_304         NM_001651.4            AQP5
# ...               ...                 ...             ...
# 81485         pLX_304              eGFP.1            eGFP
# 81486         pLX_304              eGFP.1            eGFP
# 81487         pLX_304              eGFP.1            eGFP
# 81488         pLX_304              eGFP.1            eGFP
# 81489         pLX_304              eGFP.1            eGFP
#
#       Metadata_NCBI_Gene_ID Metadata_Taxon_ID  \
# 0                         9              9606
# 1                        56              9606
# 2                       177              9606
# 3                       307              9606
# 4                       362              9606
# ...                     ...               ...
# 81485                  eGFP           CONTROL
# 81486                  eGFP           CONTROL
# 81487                  eGFP           CONTROL
# 81488                  eGFP           CONTROL
# 81489                  eGFP           CONTROL
#
#                                Metadata_Gene_Description  Metadata_Prot_Match  \
# 0                                  N-acetyltransferase 1                100.0
# 1                            acrosomal vesicle protein 1                100.0
# 2      advanced glycosylation end-product specific re...                100.0
# 3                                             annexin A4                100.0
# 4                                            aquaporin 5                100.0
# ...                                                  ...                  ...
# 81485                                      Hahn Lab eGFP                100.0
# 81486                                      Hahn Lab eGFP                100.0
# 81487                                      Hahn Lab eGFP                100.0
# 81488                                      Hahn Lab eGFP                100.0
# 81489                                      Hahn Lab eGFP                100.0
#
#        ...  Nuclei_Texture_Variance_RNA_10_03_256  \
# 0      ...                              82.875999
# 1      ...                              93.607002
# 2      ...                             133.380005
# 3      ...                              84.871002
# 4      ...                              91.669998
# ...    ...                                    ...
# 81485  ...                              55.507999
# 81486  ...                              82.763000
# 81487  ...                              80.323997
# 81488  ...                              64.931999
# 81489  ...                              57.710999
#
#       Nuclei_Texture_Variance_RNA_3_00_256  \
# 0                                76.996002
# 1                                88.196999
# 2                               126.150002
# 3                                80.910004
# 4                                87.241997
# ...                                    ...
# 81485                            52.641998
# 81486                            78.248001
# 81487                            75.813004
# 81488                            60.368000
# 81489                            54.028999
#
#       Nuclei_Texture_Variance_RNA_3_01_256  \
# 0                                77.473999
# 1                                89.211998
# 2                               127.250000
# 3                                81.814003
# 4                                87.132004
# ...                                    ...
# 81485                            52.819000
# 81486                            78.682999
# 81487                            75.680000
# 81488                            60.714001
# 81489                            54.479000
#
#       Nuclei_Texture_Variance_RNA_3_02_256  \
# 0                                76.582001
# 1                                88.081001
# 2                               125.769997
# 3                                80.850998
# 4                                86.538002
# ...                                    ...
# 81485                            52.685001
# 81486                            78.156998
# 81487                            75.359001
# 81488                            60.174999
# 81489                            54.161999
#
#       Nuclei_Texture_Variance_RNA_3_03_256  \
# 0                                77.233002
# 1                                89.154999
# 2                               127.250000
# 3                                81.926003
# 4                                87.476997
# ...                                    ...
# 81485                            52.908001
# 81486                            78.873001
# 81487                            75.810997
# 81488                            60.575001
# 81489                            54.435001
#
#       Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                                78.186996
# 1                                89.897003
# 2                               128.429993
# 3                                82.567001
# 4                                88.224998
# ...                                    ...
# 81485                            53.057999
# 81486                            79.271004
# 81487                            76.195000
# 81488                            60.935001
# 81489                            54.666000
#
#        Nuclei_Texture_Variance_RNA_5_01_256  \
# 0                                 80.055000
# 1                                 92.719002
# 2                                131.880005
# 3                                 85.179001
# 4                                 90.223000
# ...                                     ...
# 81485                             54.457001
# 81486                             81.320000
# 81487                             77.635002
# 81488                             62.526001
# 81489                             56.235001
#
#        Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                                 77.632004
# 1                                 89.843002
# 2                                127.940002
# 3                                 82.646004
# 4                                 87.663002
# ...                                     ...
# 81485                             53.095001
# 81486                             79.264000
# 81487                             75.720001
# 81488                             60.872002
# 81489                             54.730000
#
#        Nuclei_Texture_Variance_RNA_5_03_256      Metadata_Batch
# 0                                 79.955002   2021_06_21_Batch7
# 1                                 92.597000   2021_06_21_Batch7
# 2                                131.960007   2021_06_21_Batch7
# 3                                 85.292999   2021_06_21_Batch7
# 4                                 90.227997   2021_06_21_Batch7
# ...                                     ...                 ...
# 81485                             54.158001  2021_08_30_Batch13
# 81486                             81.386002  2021_08_30_Batch13
# 81487                             77.588997  2021_08_30_Batch13
# 81488                             62.504002  2021_08_30_Batch13
# 81489                             56.094002  2021_08_30_Batch13
#
# [81490 rows x 4780 columns]

# %% [markdown]
# #### Save filtered profiles with metadata

# %%
ann_df.to_parquet("output/raw_filtered_profiles_with_poscon.parquet", index=False)

# %% [markdown]
# #### Make sure no metadata columns weren't matched when merging

# %%
# list features ending with either "_x" or "_y", case insensitive
ann_df.columns[ann_df.columns.str.contains("(_x|_y)$", case=False)]
# Out:
# /var/folders/24/rq9nr3254ks1cny3_83r43bc0000gp/T/ipykernel_41305/3356552406.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   ann_df.columns[ann_df.columns.str.contains("(_x|_y)$", case=False)]
# Index(['Cells_AreaShape_BoundingBoxMaximum_X',
#        'Cells_AreaShape_BoundingBoxMaximum_Y',
#        'Cells_AreaShape_BoundingBoxMinimum_X',
#        'Cells_AreaShape_BoundingBoxMinimum_Y', 'Cells_AreaShape_Center_X',
#        'Cells_AreaShape_Center_Y', 'Cytoplasm_AreaShape_BoundingBoxMaximum_X',
#        'Cytoplasm_AreaShape_BoundingBoxMaximum_Y',
#        'Cytoplasm_AreaShape_BoundingBoxMinimum_X',
#        'Cytoplasm_AreaShape_BoundingBoxMinimum_Y',
#        'Cytoplasm_AreaShape_Center_X', 'Cytoplasm_AreaShape_Center_Y',
#        'Nuclei_AreaShape_BoundingBoxMaximum_X',
#        'Nuclei_AreaShape_BoundingBoxMaximum_Y',
#        'Nuclei_AreaShape_BoundingBoxMinimum_X',
#        'Nuclei_AreaShape_BoundingBoxMinimum_Y', 'Nuclei_AreaShape_Center_X',
#        'Nuclei_AreaShape_Center_Y', 'Nuclei_Location_Center_X',
#        'Nuclei_Location_Center_Y'],
#       dtype='object')
