# %% [markdown]
# ## Normalize and select CP features using Pycytominer

# %%
import pandas as pd
from preprocess import preprocess_profiles

# %%
profiles = pd.read_parquet("input/raw_profiles.parquet")
profiles.head()
# Out:
#   Metadata_Source Metadata_Plate Metadata_Well  Cells_AreaShape_Area  \
# 0        source_4     BR00117035           A01           5834.000000
# 1        source_4     BR00117035           A02           5463.799805
# 2        source_4     BR00117035           A03           5416.000000
# 3        source_4     BR00117035           A04           5949.799805
# 4        source_4     BR00117035           A05           5820.700195
#
#    Cells_AreaShape_BoundingBoxArea  Cells_AreaShape_BoundingBoxMaximum_X  \
# 0                          12214.0                            569.679993
# 1                          11298.0                            573.630005
# 2                          10838.0                            602.969971
# 3                          12099.0                            606.369995
# 4                          11727.0                            574.479980
#
#    Cells_AreaShape_BoundingBoxMaximum_Y  Cells_AreaShape_BoundingBoxMinimum_X  \
# ...

# %%
profiles.shape
# Out:
# (106352, 4771)

# %% [markdown]
# ##### Run feature normalization with `RobustMAD`, followed by feature selection

# %%
profiles = preprocess_profiles(profiles)
profiles.head()
# Out:
#   Metadata_Source Metadata_Plate Metadata_Well  Cells_AreaShape_Area  \
# 0        source_4     BR00117035           A01             -0.573138
# 1        source_4     BR00117035           A02             -1.453902
# 2        source_4     BR00117035           A03             -1.567626
# 3        source_4     BR00117035           A04             -0.297633
# 4        source_4     BR00117035           A05             -0.604781
#
#    Cells_AreaShape_BoundingBoxArea  Cells_AreaShape_BoundingBoxMaximum_X  \
# 0                         0.173641                             -1.225808
# 1                        -0.745754                             -0.965628
# 2                        -1.207459                              0.966946
# 3                         0.058215                              1.190900
# 4                        -0.315164                             -0.909641
#
#    Cells_AreaShape_BoundingBoxMaximum_Y  Cells_AreaShape_BoundingBoxMinimum_X  \
# ...

# %% [markdown]
# Save preprocessed profiles

# %%
profiles.to_parquet("output/processed_profiles.parquet")
