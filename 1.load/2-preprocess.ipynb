# %% [markdown]
# ## Normalize and select CP features using Pycytominer

# %%
import pandas as pd

# to install pycytominer, run `poetry run pip install <path_to_pycytominer>`
from pycytominer import normalize, feature_select

# %% [markdown]
# Predefine parameters for feature normalization (RobustMAD) and selection

# %%
MAD_EPSILON = 0.0
INC_IMAGE_FEATURES = True
FEAT_SELECT_OPS = ["variance_threshold", "correlation_threshold", "drop_na_columns", "blocklist"]

# %%
profiles = pd.read_parquet("output/raw_profiles.parquet")
profiles.head()
# Out:
#   Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 1   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 2   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 3   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 4   JCP2022_900007    ccsbBroad304_00009  ORF009407.1_TRC304.1
#
#   Metadata_Vector Metadata_Transcript Metadata_Symbol Metadata_NCBI_Gene_ID  \
# 0         pLX_304         NM_000663.4            ABAT                    18
# 1         pLX_304         NM_000663.4            ABAT                    18
# 2         pLX_304         NM_000663.4            ABAT                    18
# 3         pLX_304         NM_000663.4            ABAT                    18
# 4         pLX_304         NM_001096.3            ACLY                    47
#
#   Metadata_Taxon_ID         Metadata_Gene_Description  Metadata_Prot_Match  \
# 0              9606  4-aminobutyrate aminotransferase                100.0
# 1              9606  4-aminobutyrate aminotransferase                100.0
# 2              9606  4-aminobutyrate aminotransferase                100.0
# 3              9606  4-aminobutyrate aminotransferase                100.0
# 4              9606                 ATP citrate lyase                100.0
#
#    Metadata_Insert_Length Metadata_pert_type Metadata_Source Metadata_Plate  \
# 0                  1500.0                trt        source_4     BR00125633
# 1                  1500.0                trt        source_4     BR00125634
# 2                  1500.0                trt        source_4     BR00125635
# 3                  1500.0                trt        source_4     BR00125636
# 4                  3303.0                trt        source_4     BR00125633
#
#   Metadata_Well  Cells_AreaShape_Eccentricity  Nuclei_AreaShape_Area
# 0           M20                       0.78118                 1074.6
# 1           M20                       0.77979                 1103.1
# 2           M20                       0.77770                 1111.2
# 3           M20                       0.79073                 1085.8
# 4           F03                       0.78059                 1053.1

# %% [markdown]
# Run feature normalization with `RobustMAD`

# %%
profiles = normalize(profiles, method="mad_robustize", mad_robustize_epsilon=MAD_EPSILON, image_features=INC_IMAGE_FEATURES)
profiles.head()
# Out:
#   Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 1   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 2   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 3   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 4   JCP2022_900007    ccsbBroad304_00009  ORF009407.1_TRC304.1
#
#   Metadata_Vector Metadata_Transcript Metadata_Symbol Metadata_NCBI_Gene_ID  \
# 0         pLX_304         NM_000663.4            ABAT                    18
# 1         pLX_304         NM_000663.4            ABAT                    18
# 2         pLX_304         NM_000663.4            ABAT                    18
# 3         pLX_304         NM_000663.4            ABAT                    18
# 4         pLX_304         NM_001096.3            ACLY                    47
#
#   Metadata_Taxon_ID         Metadata_Gene_Description  Metadata_Prot_Match  \
# 0              9606  4-aminobutyrate aminotransferase                100.0
# 1              9606  4-aminobutyrate aminotransferase                100.0
# 2              9606  4-aminobutyrate aminotransferase                100.0
# 3              9606  4-aminobutyrate aminotransferase                100.0
# 4              9606                 ATP citrate lyase                100.0
#
#    Metadata_Insert_Length Metadata_pert_type Metadata_Source Metadata_Plate  \
# 0                  1500.0                trt        source_4     BR00125633
# 1                  1500.0                trt        source_4     BR00125634
# 2                  1500.0                trt        source_4     BR00125635
# 3                  1500.0                trt        source_4     BR00125636
# 4                  3303.0                trt        source_4     BR00125633
#
#   Metadata_Well  Cells_AreaShape_Eccentricity  Nuclei_AreaShape_Area
# 0           M20                     -0.186118              -0.384347
# 1           M20                     -0.393081               0.689563
# 2           M20                     -0.704270               0.994780
# 3           M20                      1.235822               0.037681
# 4           F03                     -0.273965              -1.194489

# %% [markdown]
# Run feature selection

# %%
profiles = feature_select(profiles, operation=FEAT_SELECT_OPS, image_features=INC_IMAGE_FEATURES)
profiles.head()
# Out:
#   Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 1   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 2   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 3   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 4   JCP2022_900007    ccsbBroad304_00009  ORF009407.1_TRC304.1
#
#   Metadata_Vector Metadata_Transcript Metadata_Symbol Metadata_NCBI_Gene_ID  \
# 0         pLX_304         NM_000663.4            ABAT                    18
# 1         pLX_304         NM_000663.4            ABAT                    18
# 2         pLX_304         NM_000663.4            ABAT                    18
# 3         pLX_304         NM_000663.4            ABAT                    18
# 4         pLX_304         NM_001096.3            ACLY                    47
#
#   Metadata_Taxon_ID         Metadata_Gene_Description  Metadata_Prot_Match  \
# 0              9606  4-aminobutyrate aminotransferase                100.0
# 1              9606  4-aminobutyrate aminotransferase                100.0
# 2              9606  4-aminobutyrate aminotransferase                100.0
# 3              9606  4-aminobutyrate aminotransferase                100.0
# 4              9606                 ATP citrate lyase                100.0
#
#    Metadata_Insert_Length Metadata_pert_type Metadata_Source Metadata_Plate  \
# 0                  1500.0                trt        source_4     BR00125633
# 1                  1500.0                trt        source_4     BR00125634
# 2                  1500.0                trt        source_4     BR00125635
# 3                  1500.0                trt        source_4     BR00125636
# 4                  3303.0                trt        source_4     BR00125633
#
#   Metadata_Well  Cells_AreaShape_Eccentricity  Nuclei_AreaShape_Area
# 0           M20                     -0.186118              -0.384347
# 1           M20                     -0.393081               0.689563
# 2           M20                     -0.704270               0.994780
# 3           M20                      1.235822               0.037681
# 4           F03                     -0.273965              -1.194489

# %% [markdown]
# Save preprocessed profiles

# %%
profiles.to_parquet("output/processed_profiles.parquet")
