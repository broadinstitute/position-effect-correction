# %%
import glob
import pandas as pd
from preprocess import preprocess_profiles

# %% [markdown]
# ### Preprocessing parameters

# %%
MAD_EPSILON = 0.0
INC_IMAGE_FEATURES = True
FEAT_SELECT_OPS = ["variance_threshold", "correlation_threshold", "drop_na_columns", "blocklist"]

# %% [markdown]
# ### List plates with overlapping ORFs
#
# See https://github.com/jump-cellpainting/jump-cellpainting/issues/78#issuecomment-805942281

# %%
JCP_OVERLAP_PLATES = [
    "OKA05.06.07.08.A",
    "OAB84.85.86.87.A",
    "OAA97.98.99.XX.A",
    "OAB25.26.27.28.A",
    "OAB41.OAC17.OAB78.79.A",
    "OAA49.59.79.80.A",
    "OAA58.60.61.62.A",
    "OAA85.86.87.88.A",
    "OAB13.14.15.16.A",
    "OAB33.34.35.36.A",
    "OAB37.38.39.40.A",
]

# %% [markdown]
# ### Read platemaps
#
# First need to pull them from https://github.com/jump-cellpainting/jump-orf-data/tree/master/metadata/platemaps

# %%
platemaps = glob.glob("../../jump-orf-data/metadata/platemaps/*/*.csv")
platemaps = pd.concat((pd.read_csv(f) for f in platemaps), ignore_index=True)
assert ~platemaps.duplicated().any()

platemaps.columns = ["Metadata_Plate", "Metadata_Plate_Map_Name"]
platemaps
# Out:
#     Metadata_Plate          Metadata_Plate_Map_Name
# 0       BR00126544                          control
# 1       BR00121426  JUMP-Target-2_compound_platemap
# 2       BR00126542                 OAB37.38.39.40.A
# 3       BR00126541                 OAB37.38.39.40.A
# 4       BR00126540                 OAB37.38.39.40.A
# ..             ...                              ...
# 272     BR00123627              OAA41.42.43.OAB45.A
# 273     BR00123628              OAA41.42.43.OAB45.A
# 274     BR00123629              OAA41.42.43.OAB45.A
# 275     BR00123621              OAA41.42.43.OAB45.A
# 276     BR00123622              OAA41.42.43.OAB45.A
#
# [277 rows x 2 columns]

# %% [markdown]
# See distribution of number of replicates per plate map

# %%
platemaps.groupby("Metadata_Plate_Map_Name").count().value_counts()
# Out:
# Metadata_Plate
# 5                 41
# 6                  2
# 10                 2
# 4                  1
# 14                 1
# 22                 1
# dtype: int64

# %% [markdown]
# ### Select first 5 plates for each overlapping platemap

# %%
# select only JCP overlap plates
overlap_plates = platemaps[platemaps["Metadata_Plate_Map_Name"].isin(JCP_OVERLAP_PLATES)]

# select first 2 plates from each plate map
overlap_plates = overlap_plates.groupby("Metadata_Plate_Map_Name").head(5)

overlap_plates
# Out:
#     Metadata_Plate Metadata_Plate_Map_Name
# 2       BR00126542        OAB37.38.39.40.A
# 3       BR00126541        OAB37.38.39.40.A
# 4       BR00126540        OAB37.38.39.40.A
# 5       BR00126539        OAB37.38.39.40.A
# 6       BR00126538        OAB37.38.39.40.A
# 41      BR00125164        OAA58.60.61.62.A
# 42      BR00125163        OAA58.60.61.62.A
# 43      BR00125162        OAA58.60.61.62.A
# 44      BR00124785        OAA58.60.61.62.A
# 45      BR00124784        OAA58.60.61.62.A
# 63      BR00121556        OAA97.98.99.XX.A
# 64      BR00121555        OAA97.98.99.XX.A
# 65      BR00121554        OAA97.98.99.XX.A
# 66      BR00121553        OAA97.98.99.XX.A
# 67      BR00121552        OAA97.98.99.XX.A
# 103     BR00123787  OAB41.OAC17.OAB78.79.A
# 104     BR00123786  OAB41.OAC17.OAB78.79.A
# 105     BR00123785  OAB41.OAC17.OAB78.79.A
# 106     BR00123791  OAB41.OAC17.OAB78.79.A
# 107     BR00123790  OAB41.OAC17.OAB78.79.A
# 142     BR00117041        OAB84.85.86.87.A
# 143     BR00117040        OAB84.85.86.87.A
# 144     BR00117039        OAB84.85.86.87.A
# 145     BR00117038        OAB84.85.86.87.A
# 146     BR00117037        OAB84.85.86.87.A
# 149     BR00126399        OAB33.34.35.36.A
# 150     BR00126398        OAB33.34.35.36.A
# 151     BR00126397        OAB33.34.35.36.A
# 152     BR00126396        OAB33.34.35.36.A
# 153     BR00126395        OAB33.34.35.36.A
# 171     BR00123947        OAA49.59.79.80.A
# 172     BR00123948        OAA49.59.79.80.A
# 173     BR00123949        OAA49.59.79.80.A
# 174     BR00123950        OAA49.59.79.80.A
# 175     BR00123951        OAA49.59.79.80.A
# 197     BR00125621        OAA85.86.87.88.A
# 198     BR00125620        OAA85.86.87.88.A
# 199     BR00125619        OAA85.86.87.88.A
# 200     BR00124788        OAA85.86.87.88.A
# 201     BR00124787        OAA85.86.87.88.A
# 218     BR00124766        OKA05.06.07.08.A
# 219     BR00124767        OKA05.06.07.08.A
# 220     BR00124768        OKA05.06.07.08.A
# 221     BR00124769        OKA05.06.07.08.A
# 222     BR00123945        OKA05.06.07.08.A
# 235     BR00126060        OAB13.14.15.16.A
# 236     BR00126057        OAB13.14.15.16.A
# 237     BR00126058        OAB13.14.15.16.A
# 238     BR00126059        OAB13.14.15.16.A
# 239     BR00126056        OAB13.14.15.16.A
# 257     BR00123616        OAB25.26.27.28.A
# 258     BR00123617        OAB25.26.27.28.A
# 259     BR00123618        OAB25.26.27.28.A
# 260     BR00123613        OAB25.26.27.28.A
# 261     BR00123614        OAB25.26.27.28.A

# %% [markdown]
# ### Read profiles

# %%
ann_df = pd.read_parquet("output/raw_filtered_profiles.parquet")
ann_df.head()
# Out:
#   Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0   JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 1   JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 2   JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 3   JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
# 4   JCP2022_900002    ccsbBroad304_00001  ORF008415.1_TRC304.1
#
#   Metadata_Vector Metadata_Transcript Metadata_Symbol Metadata_NCBI_Gene_ID  \
# 0         pLX_304      NM_001160173.3            NAT1                     9
# 1         pLX_304      NM_001160173.3            NAT1                     9
# 2         pLX_304      NM_001160173.3            NAT1                     9
# 3         pLX_304      NM_001160173.3            NAT1                     9
# 4         pLX_304      NM_001160173.3            NAT1                     9
#
#   Metadata_Taxon_ID Metadata_Gene_Description  Metadata_Prot_Match  ...  \
# 0              9606     N-acetyltransferase 1                100.0  ...
# 1              9606     N-acetyltransferase 1                100.0  ...
# 2              9606     N-acetyltransferase 1                100.0  ...
# 3              9606     N-acetyltransferase 1                100.0  ...
# 4              9606     N-acetyltransferase 1                100.0  ...
#
#    Nuclei_Texture_Variance_RNA_10_02_256  \
# 0                              82.535004
# 1                              72.304001
# 2                              91.155998
# 3                              71.458000
# 4                              62.820999
#
#   Nuclei_Texture_Variance_RNA_10_03_256 Nuclei_Texture_Variance_RNA_3_00_256  \
# 0                             82.875999                            76.996002
# 1                             70.678001                            67.073997
# 2                             89.515999                            84.224998
# 3                             70.707001                            66.263000
# 4                             61.692001                            58.573002
#
#   Nuclei_Texture_Variance_RNA_3_01_256 Nuclei_Texture_Variance_RNA_3_02_256  \
# 0                            77.473999                            76.582001
# 1                            67.804001                            67.042000
# 2                            84.994003                            84.225998
# 3                            67.061996                            66.330002
# 4                            58.917000                            58.855999
#
#    Nuclei_Texture_Variance_RNA_3_03_256  Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                             77.233002                             78.186996
# 1                             67.779999                             68.393997
# 2                             85.214996                             85.594002
# 3                             67.092003                             67.583000
# 4                             59.345001                             59.471001
#
#    Nuclei_Texture_Variance_RNA_5_01_256  Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                             80.055000                             77.632004
# 1                             70.334999                             68.253998
# 2                             88.263000                             85.778000
# 3                             69.570000                             67.693001
# 4                             61.160000                             59.660000
#
#    Nuclei_Texture_Variance_RNA_5_03_256
# 0                             79.955002
# 1                             70.283997
# 2                             88.174004
# 3                             69.511002
# 4                             61.311001
#
# [5 rows x 4777 columns]

# %% [markdown]
# ### Keep only selected plates

# %%
ann_df = ann_df.merge(overlap_plates, on="Metadata_Plate")
print(f"{ann_df.shape=}")
ann_df.groupby("Metadata_Plate")["Metadata_Well"].count()
# Out:
# ann_df.shape=(19144, 4778)
# Metadata_Plate
# BR00117037    353
# BR00117038    353
# BR00117039    353
# BR00117040    353
# BR00117041    353
# BR00121552    268
# BR00121553    268
# BR00121554    268
# BR00121555    268
# BR00121556    268
# BR00123613    358
# BR00123614    358
# BR00123616    358
# BR00123617    358
# BR00123618    358
# BR00123785    355
# BR00123786    355
# BR00123787    355
# BR00123790    355
# BR00123791    355
# BR00123945    354
# BR00123947    354
# BR00123948    354
# BR00123949    354
# BR00123950    354
# BR00123951    354
# BR00124766    354
# BR00124767    354
# BR00124768    354
# BR00124769    354
# BR00124784    354
# BR00124785    354
# BR00124787    360
# BR00124788    360
# BR00125162    354
# BR00125163    354
# BR00125164    354
# BR00125619    359
# BR00125620    360
# BR00125621    360
# BR00126056    357
# BR00126057    357
# BR00126058    357
# BR00126059    357
# BR00126060    357
# BR00126395    359
# BR00126396    359
# BR00126397    359
# BR00126398    359
# BR00126399    359
# BR00126538    357
# BR00126539    357
# BR00126540    357
# BR00126541    357
# BR00126542    357
# Name: Metadata_Well, dtype: int64

# %% [markdown]
# ### Save subset profiles

# %%
ann_df.to_parquet("output/subset_profiles.parquet", index=False)

# %% [markdown]
# ### Preprocess subset features

# %%
ann_df = preprocess_profiles(ann_df)
ann_df.shape
# Out:
# (19143, 584)

# %% [markdown]
# ### Save processed subset profiles

# %%
ann_df.to_parquet("output/subset_processed_profiles.parquet", index=False)
