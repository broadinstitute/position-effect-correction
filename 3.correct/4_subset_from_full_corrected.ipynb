# %%
import pandas as pd

# %%
subset_metadata = pd.read_parquet("output/subset_profiles_mean_corrected_preprocessed.parquet")
subset_metadata = subset_metadata.loc[:, ("Metadata_JCP2022", "Metadata_Plate", "Metadata_Well")]
subset_metadata
# Out:
#       Metadata_JCP2022 Metadata_Plate Metadata_Well
# 0       JCP2022_900006     BR00126538           B21
# 1       JCP2022_900176     BR00126538           I15
# 2       JCP2022_900198     BR00126538           K21
# 3       JCP2022_900294     BR00126538           L17
# 4       JCP2022_900295     BR00126538           L20
# ...                ...            ...           ...
# 19138   JCP2022_915130     BR00123791           M12
# 19139   JCP2022_915131     BR00123791           F17
# 19140   JCP2022_915131     BR00123791           I10
# 19141   JCP2022_915131     BR00123791           K09
# 19142   JCP2022_915131     BR00123791           P08
#
# [19143 rows x 3 columns]

# %%
full_corrected_profiles = pd.read_parquet("output/full_profiles_mean_corrected_preprocessed.parquet")
full_corrected_profiles_subset = full_corrected_profiles.merge(subset_metadata, on=("Metadata_JCP2022", "Metadata_Plate", "Metadata_Well"))
full_corrected_profiles_subset
# Out:
#       Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0       JCP2022_900006    ccsbBroad304_00008  ORF000425.1_TRC304.1
# 1       JCP2022_900176    ccsbBroad304_00189  ORF011559.1_TRC304.1
# 2       JCP2022_900198    ccsbBroad304_00212  ORF000189.1_TRC304.1
# 3       JCP2022_900294    ccsbBroad304_00321  ORF012872.1_TRC304.1
# 4       JCP2022_900295    ccsbBroad304_00322  ORF012041.1_TRC304.1
# ...                ...                   ...                   ...
# 19138   JCP2022_915130    ccsbBroad304_99991  ORFC00003.1_TRC304.1
# 19139   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 19140   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 19141   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 19142   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
#
#       Metadata_Vector Metadata_Transcript Metadata_Symbol  \
# 0             pLX_304         NM_001095.4           ASIC1
# 1             pLX_304         NM_000587.4              C7
# 2             pLX_304         NM_001745.4           CAMLG
# 3             pLX_304         NM_001830.4           CLCN4
# 4             pLX_304         NM_000084.5           CLCN5
# ...               ...                 ...             ...
# 19138         pLX_304        promegaLuc.1      LUCIFERASE
# 19139         pLX_304              LacZ.1            LacZ
# 19140         pLX_304              LacZ.1            LacZ
# 19141         pLX_304              LacZ.1            LacZ
# 19142         pLX_304              LacZ.1            LacZ
#
#       Metadata_NCBI_Gene_ID Metadata_Taxon_ID  \
# 0                        41              9606
# 1                       730              9606
# 2                       819              9606
# 3                      1183              9606
# 4                      1184              9606
# ...                     ...               ...
# 19138            LUCIFERASE           CONTROL
# 19139                  LacZ           CONTROL
# 19140                  LacZ           CONTROL
# 19141                  LacZ           CONTROL
# 19142                  LacZ           CONTROL
#
#                 Metadata_Gene_Description  Metadata_Prot_Match  ...  \
# 0      acid sensing ion channel subunit 1                100.0  ...
# 1                           complement C7                100.0  ...
# 2               calcium modulating ligand                100.0  ...
# 3        chloride voltage-gated channel 4                100.0  ...
# 4        chloride voltage-gated channel 5                100.0  ...
# ...                                   ...                  ...  ...
# 19138                          promegaLuc                100.0  ...
# 19139                       Hahn Lab LacZ                100.0  ...
# 19140                       Hahn Lab LacZ                100.0  ...
# 19141                       Hahn Lab LacZ                100.0  ...
# 19142                       Hahn Lab LacZ                100.0  ...
#
#        Nuclei_Texture_InfoMeas1_AGP_5_00_256  \
# 0                                   0.104431
# 1                                  -0.637207
# 2                                  -0.366019
# 3                                  -0.278863
# 4                                  -0.411728
# ...                                      ...
# 19138                              -4.384237
# 19139                              -3.266460
# 19140                              -3.870633
# 19141                              -4.390816
# 19142                              -3.127070
#
#       Nuclei_Texture_InfoMeas1_AGP_5_01_256  \
# 0                                  0.825446
# 1                                 -0.019993
# 2                                  0.167260
# 3                                  0.220977
# 4                                  0.167849
# ...                                     ...
# 19138                             -2.593292
# 19139                             -1.702388
# 19140                             -2.061786
# 19141                             -2.741054
# 19142                             -2.030196
#
#       Nuclei_Texture_InfoMeas1_DNA_3_00_256  \
# 0                                  0.744631
# 1                                  0.196188
# 2                                  0.779520
# 3                                  0.303991
# 4                                  0.108782
# ...                                     ...
# 19138                             -0.605437
# 19139                             -0.048566
# 19140                             -0.373506
# 19141                             -0.546783
# 19142                             -0.567431
#
#       Nuclei_Texture_InfoMeas1_ER_3_00_256  \
# 0                                -0.327512
# 1                                -1.427064
# 2                                -0.185799
# 3                                -0.615109
# 4                                -1.151806
# ...                                    ...
# 19138                            -3.092891
# 19139                            -2.162860
# 19140                            -2.630412
# 19141                            -3.017674
# 19142                            -2.783692
#
#       Nuclei_Texture_InfoMeas1_ER_3_03_256  \
# 0                                 0.322962
# 1                                -0.102172
# 2                                 0.519856
# 3                                 0.316870
# 4                                -0.187147
# ...                                    ...
# 19138                            -1.038312
# 19139                            -0.515805
# 19140                            -0.728392
# 19141                            -1.115662
# 19142                            -0.816252
#
#       Nuclei_Texture_InfoMeas1_Mito_3_03_256  \
# 0                                   0.561517
# 1                                  -0.376877
# 2                                   0.803967
# 3                                  -0.341202
# 4                                  -1.389762
# ...                                      ...
# 19138                              -2.530485
# 19139                              -1.840320
# 19140                              -2.871279
# 19141                              -2.317097
# 19142                              -1.261550
#
#       Nuclei_Texture_InfoMeas1_RNA_3_00_256  \
# 0                                  0.112995
# 1                                 -0.244356
# 2                                  0.269829
# 3                                 -0.079860
# 4                                 -0.846701
# ...                                     ...
# 19138                              0.298367
# 19139                              0.426918
# 19140                              0.809792
# 19141                              1.257930
# 19142                              0.207968
#
#        Nuclei_Texture_InfoMeas2_AGP_3_00_256  \
# 0                                  -0.938771
# 1                                  -0.057209
# 2                                  -0.015324
# 3                                  -0.338572
# 4                                  -0.178636
# ...                                      ...
# 19138                               2.082258
# 19139                               1.373068
# 19140                               1.944494
# 19141                               2.191990
# 19142                               1.357798
#
#        Nuclei_Texture_InfoMeas2_ER_3_02_256  \
# 0                                 -0.540046
# 1                                 -0.142832
# 2                                 -0.789447
# 3                                 -0.528488
# 4                                  0.108683
# ...                                     ...
# 19138                              0.143155
# 19139                             -0.314169
# 19140                             -0.284453
# 19141                             -0.155063
# 19142                              0.018380
#
#        Nuclei_Texture_SumVariance_AGP_5_00_256
# 0                                    -0.401067
# 1                                    -0.576551
# 2                                    -0.595972
# 3                                    -0.628293
# 4                                    -0.177422
# ...                                        ...
# 19138                                -0.735069
# 19139                                -0.431144
# 19140                                -0.743152
# 19141                                -0.515102
# 19142                                -0.750300
#
# [19143 rows x 649 columns]

# %%
full_corrected_profiles_subset.to_parquet("output/full_profiles_mean_corrected_preprocessed_subset.parquet", index=False)
