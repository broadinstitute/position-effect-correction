# %%
import pandas as pd

# %%
subset_metadata = pd.read_parquet(
    "output/subset_profiles_mean_corrected_preprocessed.parquet"
)
subset_metadata = subset_metadata.loc[
    :, ("Metadata_JCP2022", "Metadata_Plate", "Metadata_Well")
]
subset_metadata
# Out:
#       Metadata_JCP2022 Metadata_Plate Metadata_Well
# 0       JCP2022_900008     BR00117037           K06
# 1       JCP2022_900034     BR00117037           O03
# 2       JCP2022_900327     BR00117037           F09
# 3       JCP2022_900417     BR00117037           A19
# 4       JCP2022_900443     BR00117037           G18
# ...                ...            ...           ...
# 19138   JCP2022_915130     BR00126542           L04
# 19139   JCP2022_915131     BR00126542           B15
# 19140   JCP2022_915131     BR00126542           B20
# 19141   JCP2022_915131     BR00126542           E12
# 19142   JCP2022_915131     BR00126542           I05
#
# [19143 rows x 3 columns]

# %%
full_corrected_profiles = pd.read_parquet(
    "output/full_profiles_mean_corrected_preprocessed.parquet"
)
full_corrected_profiles_subset = full_corrected_profiles.merge(
    subset_metadata, on=("Metadata_JCP2022", "Metadata_Plate", "Metadata_Well")
)
full_corrected_profiles_subset
# Out:
#       Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0       JCP2022_900008    ccsbBroad304_00010  ORF011294.1_TRC304.1
# 1       JCP2022_900034    ccsbBroad304_00038  ORF001874.1_TRC304.1
# 2       JCP2022_900327    ccsbBroad304_00356  ORF005713.1_TRC304.1
# 3       JCP2022_900417    ccsbBroad304_00448  ORF010275.1_TRC304.1
# 4       JCP2022_900443    ccsbBroad304_00474  ORF014835.1_TRC304.1
# ...                ...                   ...                   ...
# 19138   JCP2022_915130    ccsbBroad304_99991  ORFC00003.1_TRC304.1
# 19139   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 19140   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 19141   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
# 19142   JCP2022_915131    ccsbBroad304_99994  ORFC00004.1_TRC304.1
#
#       Metadata_Vector Metadata_Transcript Metadata_Symbol  \
# 0             pLX_304      NM_001278352.1            ACO1
# ...

# %%
full_corrected_profiles_subset.to_parquet(
    "output/full_profiles_mean_corrected_preprocessed_subset.parquet", index=False
)
